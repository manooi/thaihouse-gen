# %%
DATASET_PATH = "./dataset/thai_house_resized_64_aug"
PROJECT_PATH = "dcgan_thaihouse64_aug_50epochs"

# %% [markdown]
# # 1. Discriminator and Generator implementation from DCGAN paper

# %%
"""
Discriminator and Generator implementation from DCGAN paper
"""

import torch
import torch.nn as nn


class Discriminator(nn.Module):

    def __init__(self, channels_img, features_d):
        super(Discriminator, self).__init__()
        self.disc = nn.Sequential(
            # Input: N x channels_img x 64 x 64
            nn.Conv2d(
                channels_img, features_d, kernel_size=4, stride=2, padding=1
            ),  # 32x32
            nn.LeakyReLU(0.2),
            self._block(features_d, features_d*2, 4, 2, 1),  # 16x16
            self._block(features_d*2, features_d*4, 4, 2, 1),  # 8x8
            self._block(features_d*4, features_d*8, 4, 2, 1),  # 4x4
            nn.Conv2d(features_d*8, 1, kernel_size=4, stride=2,
                      padding=0),  # Single-channel Output 1x1
            nn.Sigmoid(),
        )

    def _block(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.Conv2d(
                in_channels,
                out_channels,
                kernel_size,
                stride,
                padding,
                bias=False,
            ),
            nn.BatchNorm2d(out_channels),
            nn.LeakyReLU(0.2)
        )

    def forward(self, x):
        return self.disc(x)


class Generator(nn.Module):

    def __init__(self, z_dim, channels_img, features_g):
        super(Generator, self).__init__()
        self.gen = nn.Sequential(
            # Input: N x z_dim x 1 x 1
            self._block(z_dim, features_g*16, 4, 1, 0),  # N x f_g*16 x 4 x 4
            self._block(features_g*16, features_g*8, 4, 2, 1),  # 8x8
            self._block(features_g*8, features_g*4, 4, 2, 1),  # 16x16
            self._block(features_g*4, features_g*2, 4, 2, 1),  # 32x32
            nn.ConvTranspose2d(
                features_g*2,
                channels_img,
                kernel_size=4,
                stride=2,
                padding=1),
            nn.Tanh(),  # [-1, 1]
        )

    def _block(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.ConvTranspose2d(
                in_channels,
                out_channels,
                kernel_size,
                stride,
                padding,
                bias=False
            ),
            nn.BatchNorm2d(out_channels),
            nn.ReLU()
        )

    def forward(self, x):
        return self.gen(x)


def initialize_weights(model):
    # Initializes weights according to the DCGAN paper
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.ConvTranspose2d, nn.BatchNorm2d)):
            nn.init.normal_(m.weight.data, 0.0, 0.02)

# %%
"""
Training of DCGAN network on MNIST dataset with Discriminator
and Generator imported from models.py
"""

import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter
#from model import Discriminator, Generator, initialize_weights

# Hyperparameters etc.
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
LEARNING_RATE = 2e-4  # could also use two lrs, one for gen and one for disc
BATCH_SIZE = 32
IMAGE_SIZE = 64
CHANNELS_IMG = 3
NOISE_DIM = 100
NUM_EPOCHS = 50
FEATURES_DISC = 128
FEATURES_GEN = 128

transforms = transforms.Compose(
    [
        transforms.Resize(IMAGE_SIZE),
        transforms.ToTensor(),
        transforms.Normalize(
            [0.5 for _ in range(CHANNELS_IMG)], [0.5 for _ in range(CHANNELS_IMG)]
        ),
    ]
)



dataset = datasets.ImageFolder(root=DATASET_PATH, transform=transforms)
dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)


gen = Generator(NOISE_DIM, CHANNELS_IMG, FEATURES_GEN).to(device)
disc = Discriminator(CHANNELS_IMG, FEATURES_DISC).to(device)
initialize_weights(gen)
initialize_weights(disc)

opt_gen = optim.Adam(gen.parameters(), lr=LEARNING_RATE, betas=(0.5, 0.999))
opt_disc = optim.Adam(disc.parameters(), lr=LEARNING_RATE, betas=(0.5, 0.999))
criterion = nn.BCELoss()

fixed_noise = torch.randn(32, NOISE_DIM, 1, 1).to(device)
writer_real = SummaryWriter(f"tensorboard_logs/"+PROJECT_PATH+"/logs/real")
writer_fake = SummaryWriter(f"tensorboard_logs/"+PROJECT_PATH+"/logs/fake")
step = 0

gen.train()
disc.train()
# Out:
# Discriminator(
#   (disc): Sequential(
#     (0): Conv2d(3, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (3): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (4): Sequential(
#       (0): Conv2d(512, 1024, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (5): Conv2d(1024, 1, kernel_size=(4, 4), stride=(2, 2))
#     (6): Sigmoid()
#   )
# )

# %% [markdown]
# # 2. Train

# %%
log_loss_disc =[]
log_loss_gen=[]

for epoch in range(NUM_EPOCHS):
    # Target labels not needed! <3 unsupervised
    for batch_idx, (real, _) in enumerate(dataloader):
        real = real.to(device)
        noise = torch.randn(BATCH_SIZE, NOISE_DIM, 1, 1).to(device)
        fake = gen(noise)

        ### Train Discriminator: max log(D(x)) + log(1 - D(G(z)))
        disc_real = disc(real).reshape(-1)
        loss_disc_real = criterion(disc_real, torch.ones_like(disc_real))
        disc_fake = disc(fake.detach()).reshape(-1)
        loss_disc_fake = criterion(disc_fake, torch.zeros_like(disc_fake))
        loss_disc = (loss_disc_real + loss_disc_fake) / 2
        
        disc.zero_grad()
        loss_disc.backward()
        opt_disc.step()

        ### Train Generator: min log(1 - D(G(z))) <-> max log(D(G(z))
        output = disc(fake).reshape(-1)
        loss_gen = criterion(output, torch.ones_like(output))
        
        gen.zero_grad()
        loss_gen.backward()
        opt_gen.step()

        # Print losses occasionally and print to tensorboard
        if batch_idx % 100 == 0:
            print(
                f"Epoch [{epoch}/{NUM_EPOCHS}] Batch {batch_idx}/{len(dataloader)} \
                  Loss D: {loss_disc:.4f}, loss G: {loss_gen:.4f}"
            )

            with torch.no_grad():
                fake = gen(fixed_noise)
                # take out (up to) 32 examples
                img_grid_real = torchvision.utils.make_grid(
                    real[:32], normalize=True
                )
                img_grid_fake = torchvision.utils.make_grid(
                    fake[:32], normalize=True
                )

                writer_real.add_image("Real", img_grid_real, global_step=step)
                writer_fake.add_image("Fake", img_grid_fake, global_step=step)

            step += 1
            
    torch.save(gen, "./saved_models/"+PROJECT_PATH+"/gen_@"+str(epoch))
    torch.save(disc, "./saved_models/"+PROJECT_PATH+"/disc_@"+str(epoch))
    log_loss_disc.append(loss_disc)
    log_loss_gen.append(loss_gen)
# Out:
# Epoch [0/50] Batch 0/313                   Loss D: 0.6901, loss G: 0.9729
# Epoch [0/50] Batch 100/313                   Loss D: 0.3415, loss G: 4.2493
# Epoch [0/50] Batch 200/313                   Loss D: 0.3741, loss G: 3.5984
# Epoch [0/50] Batch 300/313                   Loss D: 0.5349, loss G: 2.7359
# Epoch [1/50] Batch 0/313                   Loss D: 0.3429, loss G: 3.2770
# Epoch [1/50] Batch 100/313                   Loss D: 0.3831, loss G: 2.8923
# Epoch [1/50] Batch 200/313                   Loss D: 0.4607, loss G: 2.5803
# Epoch [1/50] Batch 300/313                   Loss D: 0.4422, loss G: 3.0726
# Epoch [2/50] Batch 0/313                   Loss D: 0.5488, loss G: 1.9174
# Epoch [2/50] Batch 100/313                   Loss D: 0.4554, loss G: 2.1331
# Epoch [2/50] Batch 200/313                   Loss D: 0.3219, loss G: 2.1570
# Epoch [2/50] Batch 300/313                   Loss D: 0.5140, loss G: 1.7779
# Epoch [3/50] Batch 0/313                   Loss D: 0.4462, loss G: 2.0690
# Epoch [3/50] Batch 100/313                   Loss D: 0.4785, loss G: 1.5194
# Epoch [3/50] Batch 200/313                   Loss D: 0.4939, loss G: 2.4024
# Epoch [3/50] Batch 300/313                   Loss D: 0.3501, loss G: 2.8212
# Epoch [4/50] Batch 0/313                   Loss D: 0.4074, loss G: 2.8559
# Epoch [4/50] Batch 100/313                   Loss D: 0.4307, loss G: 4.0837
# Epoch [4/50] Batch 200/313                   Loss D: 0.3234, loss G: 3.4783
# Epoch [4/50] Batch 300/313                   Loss D: 0.3585, loss G: 2.7445
# Epoch [5/50] Batch 0/313                   Loss D: 0.3147, loss G: 3.1670
# Epoch [5/50] Batch 100/313                   Loss D: 0.2980, loss G: 2.9210
# Epoch [5/50] Batch 200/313                   Loss D: 0.3012, loss G: 2.4119
# Epoch [5/50] Batch 300/313                   Loss D: 0.4557, loss G: 2.7900
# Epoch [6/50] Batch 0/313                   Loss D: 0.2576, loss G: 2.3693
# Epoch [6/50] Batch 100/313                   Loss D: 0.2588, loss G: 3.0388
# Epoch [6/50] Batch 200/313                   Loss D: 0.1479, loss G: 3.3541
# Epoch [6/50] Batch 300/313                   Loss D: 0.4982, loss G: 4.6726
# Epoch [7/50] Batch 0/313                   Loss D: 0.2976, loss G: 4.1425
# Epoch [7/50] Batch 100/313                   Loss D: 0.2587, loss G: 2.5679
# Epoch [7/50] Batch 200/313                   Loss D: 0.3529, loss G: 4.7967
# Epoch [7/50] Batch 300/313                   Loss D: 0.3685, loss G: 3.7502
# Epoch [8/50] Batch 0/313                   Loss D: 0.1819, loss G: 3.0967
# Epoch [8/50] Batch 100/313                   Loss D: 0.2022, loss G: 3.3240
# Epoch [8/50] Batch 200/313                   Loss D: 0.2596, loss G: 2.4465
# Epoch [8/50] Batch 300/313                   Loss D: 0.7069, loss G: 3.7182
# Epoch [9/50] Batch 0/313                   Loss D: 0.2097, loss G: 2.4498
# Epoch [9/50] Batch 100/313                   Loss D: 0.1047, loss G: 5.0666
# Epoch [9/50] Batch 200/313                   Loss D: 0.2870, loss G: 2.6134
# Epoch [9/50] Batch 300/313                   Loss D: 0.3087, loss G: 6.1217
# Epoch [10/50] Batch 0/313                   Loss D: 0.2011, loss G: 4.6051
# Epoch [10/50] Batch 100/313                   Loss D: 0.1779, loss G: 4.1728
# Epoch [10/50] Batch 200/313                   Loss D: 0.1170, loss G: 5.7473
# Epoch [10/50] Batch 300/313                   Loss D: 0.1385, loss G: 4.3116
# Epoch [11/50] Batch 0/313                   Loss D: 0.4215, loss G: 6.9209
# Epoch [11/50] Batch 100/313                   Loss D: 0.1561, loss G: 4.2321
# Epoch [11/50] Batch 200/313                   Loss D: 0.6113, loss G: 8.9480
# Epoch [11/50] Batch 300/313                   Loss D: 0.2054, loss G: 5.5485
# Epoch [12/50] Batch 0/313                   Loss D: 0.1905, loss G: 5.5049
# Epoch [12/50] Batch 100/313                   Loss D: 0.0993, loss G: 4.1656
# Epoch [12/50] Batch 200/313                   Loss D: 0.0972, loss G: 4.5571
# Epoch [12/50] Batch 300/313                   Loss D: 0.1014, loss G: 4.1440
# Epoch [13/50] Batch 0/313                   Loss D: 0.2001, loss G: 3.6320
# Epoch [13/50] Batch 100/313                   Loss D: 0.1110, loss G: 4.4328
# Epoch [13/50] Batch 200/313                   Loss D: 0.1199, loss G: 4.0201
# Epoch [13/50] Batch 300/313                   Loss D: 0.0907, loss G: 5.1332
# Epoch [14/50] Batch 0/313                   Loss D: 0.1902, loss G: 5.4479
# Epoch [14/50] Batch 100/313                   Loss D: 0.1277, loss G: 3.0616
# Epoch [14/50] Batch 200/313                   Loss D: 0.1563, loss G: 4.4861
# Epoch [14/50] Batch 300/313                   Loss D: 0.0735, loss G: 4.2200
# Epoch [15/50] Batch 0/313                   Loss D: 0.0861, loss G: 6.3770
# Epoch [15/50] Batch 100/313                   Loss D: 0.0981, loss G: 5.2477
# Epoch [15/50] Batch 200/313                   Loss D: 0.6472, loss G: 5.5334
# Epoch [15/50] Batch 300/313                   Loss D: 0.1206, loss G: 4.0075
# Epoch [16/50] Batch 0/313                   Loss D: 0.0907, loss G: 4.9686
# Epoch [16/50] Batch 100/313                   Loss D: 0.0932, loss G: 6.6873
# Epoch [16/50] Batch 200/313                   Loss D: 0.6635, loss G: 2.4200
# Epoch [16/50] Batch 300/313                   Loss D: 0.0892, loss G: 4.3617
# Epoch [17/50] Batch 0/313                   Loss D: 0.0569, loss G: 4.7384
# Epoch [17/50] Batch 100/313                   Loss D: 0.1516, loss G: 5.6218
# Epoch [17/50] Batch 200/313                   Loss D: 0.0915, loss G: 5.5210
# Epoch [17/50] Batch 300/313                   Loss D: 0.0819, loss G: 5.7674
# Epoch [18/50] Batch 0/313                   Loss D: 0.0497, loss G: 5.0318
# Epoch [18/50] Batch 100/313                   Loss D: 0.2470, loss G: 3.2955
# Epoch [18/50] Batch 200/313                   Loss D: 0.0387, loss G: 5.5433
# Epoch [18/50] Batch 300/313                   Loss D: 0.0952, loss G: 6.0011
# Epoch [19/50] Batch 0/313                   Loss D: 0.0921, loss G: 3.6242
# Epoch [19/50] Batch 100/313                   Loss D: 0.1244, loss G: 4.2717
# Epoch [19/50] Batch 200/313                   Loss D: 0.0733, loss G: 5.7383
# Epoch [19/50] Batch 300/313                   Loss D: 0.1520, loss G: 3.6519
# Epoch [20/50] Batch 0/313                   Loss D: 0.0737, loss G: 5.7055
# Epoch [20/50] Batch 100/313                   Loss D: 0.0244, loss G: 5.7437
# Epoch [20/50] Batch 200/313                   Loss D: 0.0601, loss G: 4.6588
# Epoch [20/50] Batch 300/313                   Loss D: 0.0364, loss G: 5.9102
# Epoch [21/50] Batch 0/313                   Loss D: 0.8270, loss G: 7.4041
# Epoch [21/50] Batch 100/313                   Loss D: 0.1510, loss G: 3.8204
# Epoch [21/50] Batch 200/313                   Loss D: 0.0814, loss G: 4.4266
# Epoch [21/50] Batch 300/313                   Loss D: 0.2897, loss G: 10.7111
# Epoch [22/50] Batch 0/313                   Loss D: 0.0845, loss G: 6.5729
# Epoch [22/50] Batch 100/313                   Loss D: 0.0282, loss G: 5.4585
# Epoch [22/50] Batch 200/313                   Loss D: 0.0302, loss G: 6.4960
# Epoch [22/50] Batch 300/313                   Loss D: 0.0330, loss G: 5.3651
# Epoch [23/50] Batch 0/313                   Loss D: 0.0292, loss G: 6.2983
# Epoch [23/50] Batch 100/313                   Loss D: 0.1071, loss G: 6.5158
# Epoch [23/50] Batch 200/313                   Loss D: 0.0384, loss G: 5.1050
# Epoch [23/50] Batch 300/313                   Loss D: 0.1537, loss G: 2.9790
# Epoch [24/50] Batch 0/313                   Loss D: 0.2068, loss G: 7.5472
# Epoch [24/50] Batch 100/313                   Loss D: 0.0204, loss G: 6.3633
# Epoch [24/50] Batch 200/313                   Loss D: 0.0266, loss G: 5.7181
# Epoch [24/50] Batch 300/313                   Loss D: 0.0392, loss G: 8.5228
# Epoch [25/50] Batch 0/313                   Loss D: 0.0438, loss G: 5.5096
# Epoch [25/50] Batch 100/313                   Loss D: 0.1069, loss G: 6.4815
# Epoch [25/50] Batch 200/313                   Loss D: 0.1186, loss G: 3.2045
# Epoch [25/50] Batch 300/313                   Loss D: 0.0165, loss G: 6.6891
# Epoch [26/50] Batch 0/313                   Loss D: 0.0200, loss G: 6.3939
# Epoch [26/50] Batch 100/313                   Loss D: 0.1209, loss G: 8.7430
# Epoch [26/50] Batch 200/313                   Loss D: 0.0638, loss G: 4.6292
# Epoch [26/50] Batch 300/313                   Loss D: 0.1153, loss G: 8.4163
# Epoch [27/50] Batch 0/313                   Loss D: 0.0305, loss G: 5.3546
# Epoch [27/50] Batch 100/313                   Loss D: 0.0111, loss G: 8.6467
# Epoch [27/50] Batch 200/313                   Loss D: 0.0550, loss G: 8.3946
# Epoch [27/50] Batch 300/313                   Loss D: 0.0434, loss G: 5.9725
# Epoch [28/50] Batch 0/313                   Loss D: 1.7359, loss G: 18.1147
# Epoch [28/50] Batch 100/313                   Loss D: 0.1197, loss G: 6.8272
# Epoch [28/50] Batch 200/313                   Loss D: 0.0445, loss G: 4.7879
# Epoch [28/50] Batch 300/313                   Loss D: 0.1563, loss G: 2.4906
# Epoch [29/50] Batch 0/313                   Loss D: 0.0273, loss G: 6.6431
# Epoch [29/50] Batch 100/313                   Loss D: 0.2063, loss G: 3.2100
# Epoch [29/50] Batch 200/313                   Loss D: 0.0191, loss G: 4.9458
# Epoch [29/50] Batch 300/313                   Loss D: 0.0507, loss G: 6.5879
# Epoch [30/50] Batch 0/313                   Loss D: 0.0275, loss G: 6.3775
# Epoch [30/50] Batch 100/313                   Loss D: 0.0245, loss G: 6.8341
# Epoch [30/50] Batch 200/313                   Loss D: 0.0204, loss G: 6.2316
# Epoch [30/50] Batch 300/313                   Loss D: 0.0223, loss G: 6.1538
# Epoch [31/50] Batch 0/313                   Loss D: 0.0331, loss G: 7.0842
# Epoch [31/50] Batch 100/313                   Loss D: 0.0408, loss G: 6.9247
# Epoch [31/50] Batch 200/313                   Loss D: 0.0312, loss G: 5.5930
# Epoch [31/50] Batch 300/313                   Loss D: 0.0148, loss G: 6.6290
# Epoch [32/50] Batch 0/313                   Loss D: 0.0306, loss G: 5.5571
# Epoch [32/50] Batch 100/313                   Loss D: 0.0488, loss G: 5.0142
# Epoch [32/50] Batch 200/313                   Loss D: 0.0100, loss G: 7.1316
# Epoch [32/50] Batch 300/313                   Loss D: 0.0239, loss G: 6.6213
# Epoch [33/50] Batch 0/313                   Loss D: 0.0379, loss G: 7.7176
# Epoch [33/50] Batch 100/313                   Loss D: 0.0439, loss G: 6.7424
# Epoch [33/50] Batch 200/313                   Loss D: 0.0190, loss G: 6.4622
# Epoch [33/50] Batch 300/313                   Loss D: 0.0220, loss G: 5.5014
# Epoch [34/50] Batch 0/313                   Loss D: 0.0172, loss G: 7.1485
# Epoch [34/50] Batch 100/313                   Loss D: 0.1061, loss G: 6.4063
# Epoch [34/50] Batch 200/313                   Loss D: 0.0444, loss G: 8.1179
# Epoch [34/50] Batch 300/313                   Loss D: 0.0275, loss G: 5.4015
# Epoch [35/50] Batch 0/313                   Loss D: 0.0123, loss G: 6.4212
# Epoch [35/50] Batch 100/313                   Loss D: 0.0361, loss G: 6.5636
# Epoch [35/50] Batch 200/313                   Loss D: 0.0769, loss G: 5.0521
# Epoch [35/50] Batch 300/313                   Loss D: 0.0149, loss G: 6.6582
# Epoch [36/50] Batch 0/313                   Loss D: 0.1385, loss G: 9.2115
# Epoch [36/50] Batch 100/313                   Loss D: 0.0598, loss G: 7.6449
# Epoch [36/50] Batch 200/313                   Loss D: 0.0046, loss G: 8.5162
# Epoch [36/50] Batch 300/313                   Loss D: 0.0448, loss G: 5.3337
# Epoch [37/50] Batch 0/313                   Loss D: 0.0154, loss G: 7.2930
# Epoch [37/50] Batch 100/313                   Loss D: 0.0159, loss G: 6.2576
# Epoch [37/50] Batch 200/313                   Loss D: 0.4960, loss G: 21.6942
# Epoch [37/50] Batch 300/313                   Loss D: 0.2451, loss G: 12.4588
# Epoch [38/50] Batch 0/313                   Loss D: 0.0345, loss G: 7.5975
# Epoch [38/50] Batch 100/313                   Loss D: 0.0381, loss G: 6.8107
# Epoch [38/50] Batch 200/313                   Loss D: 0.0192, loss G: 6.6823
# Epoch [38/50] Batch 300/313                   Loss D: 0.0070, loss G: 6.5370
# Epoch [39/50] Batch 0/313                   Loss D: 0.0216, loss G: 7.2514
# Epoch [39/50] Batch 100/313                   Loss D: 0.0561, loss G: 4.7190
# Epoch [39/50] Batch 200/313                   Loss D: 0.0123, loss G: 6.7161
# Epoch [39/50] Batch 300/313                   Loss D: 0.0060, loss G: 8.1195
# Epoch [40/50] Batch 0/313                   Loss D: 0.0148, loss G: 7.3740
# Epoch [40/50] Batch 100/313                   Loss D: 0.0530, loss G: 8.8541
# Epoch [40/50] Batch 200/313                   Loss D: 0.0524, loss G: 6.5758
# Epoch [40/50] Batch 300/313                   Loss D: 0.0211, loss G: 6.2438
# Epoch [41/50] Batch 0/313                   Loss D: 0.0222, loss G: 6.2116
# Epoch [41/50] Batch 100/313                   Loss D: 0.0613, loss G: 7.4456
# Epoch [41/50] Batch 200/313                   Loss D: 0.1143, loss G: 10.7023
# Epoch [41/50] Batch 300/313                   Loss D: 0.0055, loss G: 7.6664
# Epoch [42/50] Batch 0/313                   Loss D: 0.0291, loss G: 7.8065
# Epoch [42/50] Batch 100/313                   Loss D: 0.0421, loss G: 5.9400
# Epoch [42/50] Batch 200/313                   Loss D: 0.1517, loss G: 8.2922
# Epoch [42/50] Batch 300/313                   Loss D: 0.0140, loss G: 6.7276
# Epoch [43/50] Batch 0/313                   Loss D: 0.0363, loss G: 7.6768
# Epoch [43/50] Batch 100/313                   Loss D: 0.0251, loss G: 6.4722
# Epoch [43/50] Batch 200/313                   Loss D: 0.0250, loss G: 6.5875
# Epoch [43/50] Batch 300/313                   Loss D: 0.0411, loss G: 9.0569
# Epoch [44/50] Batch 0/313                   Loss D: 0.0379, loss G: 8.4711
# Epoch [44/50] Batch 100/313                   Loss D: 0.0079, loss G: 7.0145
# Epoch [44/50] Batch 200/313                   Loss D: 0.0201, loss G: 5.6569
# Epoch [44/50] Batch 300/313                   Loss D: 0.0443, loss G: 8.2460
# Epoch [45/50] Batch 0/313                   Loss D: 0.0080, loss G: 7.7737
# Epoch [45/50] Batch 100/313                   Loss D: 0.0395, loss G: 6.8293
# Epoch [45/50] Batch 200/313                   Loss D: 0.0115, loss G: 7.5063
# Epoch [45/50] Batch 300/313                   Loss D: 0.0174, loss G: 5.7306
# Epoch [46/50] Batch 0/313                   Loss D: 0.0117, loss G: 6.2852
# Epoch [46/50] Batch 100/313                   Loss D: 0.0252, loss G: 7.5749
# Epoch [46/50] Batch 200/313                   Loss D: 0.0263, loss G: 9.2762
# Epoch [46/50] Batch 300/313                   Loss D: 0.0506, loss G: 4.5406
# Epoch [47/50] Batch 0/313                   Loss D: 0.0079, loss G: 5.8158
# Epoch [47/50] Batch 100/313                   Loss D: 0.0072, loss G: 9.5668
# Epoch [47/50] Batch 200/313                   Loss D: 0.0249, loss G: 8.2723
# Epoch [47/50] Batch 300/313                   Loss D: 0.0170, loss G: 6.1538
# Epoch [48/50] Batch 0/313                   Loss D: 0.1059, loss G: 8.8852
# Epoch [48/50] Batch 100/313                   Loss D: 0.1123, loss G: 11.5815
# Epoch [48/50] Batch 200/313                   Loss D: 0.0410, loss G: 5.8194
# Epoch [48/50] Batch 300/313                   Loss D: 0.0150, loss G: 7.8886
# Epoch [49/50] Batch 0/313                   Loss D: 0.0257, loss G: 6.8601
# Epoch [49/50] Batch 100/313                   Loss D: 0.0448, loss G: 5.4598
# Epoch [49/50] Batch 200/313                   Loss D: 0.0402, loss G: 8.3818
# Epoch [49/50] Batch 300/313                   Loss D: 0.0078, loss G: 5.7527

# %% [markdown]
# # 3. Load saved models

# %% [markdown]
# ### 3.1 Load generator

# %%
model = Generator(NOISE_DIM, CHANNELS_IMG, FEATURES_GEN).to(device)

# %%
# %ls "saved_models/dcgan_thaihouse64_aug_50epochs"
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is BE10-F9C3
#
#  Directory of C:\Users\siraw\Desktop\thaihouse dcgan final\saved_models\dcgan_thaihouse64_aug_50epochs
#
# 19-Jun-21  10:04 PM    <DIR>          .
# 19-Jun-21  10:04 PM    <DIR>          ..
# 19-Jun-21  07:28 PM       189,391,039 gen_@27
#                1 File(s)    189,391,039 bytes
#                2 Dir(s)  88,355,717,120 bytes free

# %%
model = torch.load("./saved_models/"+PROJECT_PATH+"/gen_@27") # Best generator @epoch27
model.train()
# Out:
# Generator(
#   (gen): Sequential(
#     (0): Sequential(
#       (0): ConvTranspose2d(100, 2048, kernel_size=(4, 4), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (1): Sequential(
#       (0): ConvTranspose2d(2048, 1024, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (2): Sequential(
#       (0): ConvTranspose2d(1024, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (3): Sequential(
#       (0): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (4): ConvTranspose2d(256, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (5): Tanh()
#   )
# )

# %% [markdown]
# # 4. Model inference

# %% [markdown]
# ### 4.0 Utility function

# %%
import matplotlib.pyplot as plt
import cv2
from skimage import img_as_ubyte
import os

# %%
def tensor_to_img(tensor, model):
    # Feed into model and reshape to (3, H, W)
    img  = model(tensor).squeeze(0).permute(1,2,0).detach().cpu().numpy()
    
    # Convert to 0-255
    img = img_as_ubyte(img)
    return img

# %%
def generate_noise(n):
    return torch.randn(1,n,1,1).to(device)

# %% [markdown]
# ### 4.1 Just one

# %%
import matplotlib.pyplot as plt
import cv2
from skimage import img_as_ubyte
import os

# %%
# Generate noise of size 100
one_noise = generate_noise(100)

# Feed into model and reshape to (3, H, W)
one_img = tensor_to_img(one_noise,  model)

# %%
plt.imshow(one_img)

# %% [markdown]
# ### 4.2 More

# %%
fig, ax = plt.subplots(nrows=4, ncols=4)
fig.set_size_inches(15, 15, forward=True)
for row in ax:
    for col in row:
        col.imshow(tensor_to_img(generate_noise(100), model))

fig.subplots_adjust(wspace=0, hspace=0.5)
plt.show()

# %% [markdown]
# ### 4.2 Generate 100 images and save

# %%
def generate_number(no, model):
    count=1
    for i in range(no):
        # Generate noise
        test_noise = torch.randn(1,100,1,1).to(device)
        
        # Feed into model and reshape to (3, H, W)
        test_img = model(test_noise).squeeze(0).permute(1,2,0).detach().cpu().numpy()
        
        # Convert to 0-255
        test_img = img_as_ubyte(test_img)
        
        # Convert to RGB (for 1 channel image only)
        # test_img = cv2.cvtColor(test_img, cv2.COLOR_GRAY2RGB)
        
        if "gen_img" not in os.listdir('./'):
            os.mkdir('gen_img')
            os.mkdir('gen_img/'+PROJECT_PATH)
        file_name = './gen_img/'+PROJECT_PATH+'/img'+str(count)+'.png'
        plt.imsave(file_name, test_img)
        count+=1

# %%
generate_number(100, model)

# %% [markdown]
# # 5. Loss

# %%
plot_discriminator_loss = [i.detach().cpu().numpy() for _, i in enumerate(log_loss_disc)]

# %% [markdown]
# ### 5.1 Discriminator

# %%
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.plot(plot_discriminator_loss)

# %% [markdown]
# ### 5.2 Generator

# %%
plot_generator_loss = [i.detach().cpu().numpy() for _, i in enumerate(log_loss_gen)]

# %%
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.plot(plot_generator_loss, alpha=0.8, color='red')

# %%
def find_min_loss(li):
    min_loss = max(li)
    position = -1
    for index, i in enumerate(li):
        if i<min_loss:
            min_loss=i
            position=index
    return min, position

# %%
find_min_loss(plot_generator_loss)
# Out:
# (<function min>, 27)

# %%
plot_generator_loss[27]
# Out:
# array(1.6797681, dtype=float32)
